# %%
from get_archived_data import prepare_gridded_radar_data_from_zip, npy_to_netcdf, get_cpc_quality_code,get_combined_max_radar_grid,get_netcdf
from datetime import datetime, timedelta
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
# for a single timestep for any product
product = "MZC" #MESHS
out_dir = '/scratch/tschmid/data/nc_files/5min'

# %%
date = dt.datetime(2021,7,12)
nc_out = get_netcdf(product,date,return_5min_data=True)
nc_out.max(dim='time').MZC.plot()
nc_out.to_netcdf(f'{out_dir}/{product}_6t6_{date.strftime("%Y-%m-%d")}.nc', encoding={product:{'zlib':True,'complevel':5}})
# Out:
# /users/tschmid/scClimCSCS/get_archived_data.py:490: UserWarning: by default MZCH will be used, which uses the 0C-line from the Analysis
#   warnings.warn(f"by default {product}H will be used, which uses the 0C-line from the Analysis")

# %%
date = dt.datetime(2021,6,28)
nc_out = get_netcdf(product,date,return_5min_data=True)
nc_out.max(dim='time').MZC.plot()
nc_out.to_netcdf(f'{out_dir}/{product}_6t6_{date.strftime("%Y-%m-%d")}.nc', encoding={product:{'zlib':True,'complevel':5}})
# Out:
# /users/tschmid/scClimCSCS/get_archived_data.py:490: UserWarning: by default MZCH will be used, which uses the 0C-line from the Analysis
#   temp_date = start_date - datetime.timedelta(

# %%
date = dt.datetime(2021,6,21)
nc_out = get_netcdf(product,date,return_5min_data=True)
nc_out.max(dim='time').MZC.plot()
nc_out.to_netcdf(f'{out_dir}/{product}_6t6_{date.strftime("%Y-%m-%d")}.nc', encoding={product:{'zlib':True,'complevel':5}})
# Out:
# /users/tschmid/scClimCSCS/get_archived_data.py:490: UserWarning: by default MZCH will be used, which uses the 0C-line from the Analysis
#   temp_date = start_date - datetime.timedelta(

# %%
date = dt.datetime(2021,6,20)
nc_out = get_netcdf(product,date,return_5min_data=True)
nc_out.max(dim='time').MZC.plot()
nc_out.to_netcdf(f'{out_dir}/{product}_6t6_{date.strftime("%Y-%m-%d")}.nc', encoding={product:{'zlib':True,'complevel':5}})
# Out:
# /users/tschmid/scClimCSCS/get_archived_data.py:490: UserWarning: by default MZCH will be used, which uses the 0C-line from the Analysis
#   temp_date = start_date - datetime.timedelta(

# %%
date = dt.datetime(2023,8,25)
nc_out = get_netcdf(product,date,return_5min_data=True)
nc_out.max(dim='time').MZC.plot()
nc_out.to_netcdf(f'{out_dir}/{product}_6t6_{date.strftime("%Y-%m-%d")}.nc', encoding={product:{'zlib':True,'complevel':5}})
# Out:
# /users/tschmid/scClimCSCS/get_archived_data.py:490: UserWarning: by default MZCH will be used, which uses the 0C-line from the Analysis
#   warnings.warn(f"by default {product}H will be used, which uses the 0C-line from the Analysis")

# %%
date = dt.datetime(2023,7,12)
nc_out = get_netcdf(product,date,return_5min_data=True)
nc_out.max(dim='time').MZC.plot()
nc_out.to_netcdf(f'{out_dir}/{product}_6t6_{date.strftime("%Y-%m-%d")}.nc', encoding={product:{'zlib':True,'complevel':5}})
# Out:
# /users/tschmid/scClimCSCS/get_archived_data.py:490: UserWarning: by default MZCH will be used, which uses the 0C-line from the Analysis
#   warnings.warn(f"by default {product}H will be used, which uses the 0C-line from the Analysis")
